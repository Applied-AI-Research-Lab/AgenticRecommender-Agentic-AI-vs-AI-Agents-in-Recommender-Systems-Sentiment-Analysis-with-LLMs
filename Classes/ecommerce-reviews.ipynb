# %%
import json
import pandas as pd
import random
import gc  # For garbage collection / memory management
from collections import Counter
from google.colab import drive
drive.mount('/content/gdrive') # Mount Google Drive
absolute_path = "/content/gdrive/My Drive/Projects/amazon-reviews/"
dataset_path = absolute_path + "Datasets/"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Download and Extract Amazon Review Datasets
#
# This section downloads the review datasets from UCSD and extracts them to the dataset path.

# %% [markdown]
# ## Important Notes for OUR Large Files
#
# UCSD datasets contain millions of reviews. Here's how we handled them efficiently:
#
# 1. **Chunked Processing**: Files are processed in 100K review chunks to avoid memory overflow
# 2. **No Early Stopping**: By default, we process entire files to ensure enough samples for rare ratings (2.0, 3.0)
# 3. **Colab Compatibility**: Works on T4 GPU (free tier), but L4 or A100 recommended for faster processing
# 4. **Memory Issues**: To avoid memory errors, we could reduce the parameters bellow (though this may result in insufficient samples after deduplication):
#    - Set `CHUNK_SIZE` to 50000
#    - Set `MAX_FILTERED_PER_CATEGORY` to 100000 (or higher if possible)

# %%
import gzip
import shutil
import os
from urllib.request import urlretrieve
from urllib.parse import urlparse

def download_and_extract(url, dataset_path):
    """
    Downloads a compressed JSONL file and extracts it.
    Skips download if file already exists to save time.
    """
    # Parse filename from URL
    filename = os.path.basename(urlparse(url).path)
    gz_path = os.path.join(dataset_path, filename)
    jsonl_path = gz_path.replace('.gz', '')

    # Skip if already extracted
    if os.path.exists(jsonl_path):
        print(f"{filename.replace('.gz', '')} already exists, skipping download.")
        return jsonl_path

    # Download compressed file
    print(f"Downloading {filename}...")
    urlretrieve(url, gz_path)
    print(f"Downloaded {filename}")

    # Extract to JSONL
    print(f"Extracting {filename}...")
    with gzip.open(gz_path, 'rb') as f_in:
        with open(jsonl_path, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
    print(f"Extracted to {os.path.basename(jsonl_path)}")

    # Clean up compressed file to save space
    os.remove(gz_path)
    print(f"Removed {filename} to save space\n")

    return jsonl_path

# %% [markdown]
# # Filter Reviews and Count
#
# This section filters reviews based on required criteria and returns statistics.

# %%
def is_valid_review(review):
    """
    Validates that a review meets all required criteria.
    We need ratings, title, text, images, and verified purchase status.
    """
    return (
        isinstance(review.get("rating"), (int, float)) and not pd.isna(review["rating"]) and
        isinstance(review.get("title"), str) and review["title"].strip() != "" and
        isinstance(review.get("text"), str) and review["text"].strip() != "" and
        isinstance(review.get("images"), list) and len(review["images"]) > 0 and
        review.get("verified_purchase") == True
    )

def filter_and_count_reviews(jsonl_path, chunk_size=100000, max_filtered=None):
    """
    Processes large JSONL files in chunks to avoid memory issues.
    Filters reviews based on validation criteria and returns clean dataset.
    """
    category_name = os.path.basename(jsonl_path).replace('.jsonl', '')
    print(f"\n{'='*60}")
    print(f"Processing: {category_name}")
    print(f"{'='*60}")

    filtered_reviews = []
    total_count = 0
    chunk_num = 0

    print("Loading and filtering reviews in chunks...")

    with open(jsonl_path, "r") as f:
        chunk = []

        for line in f:
            try:
                review = json.loads(line)
                chunk.append(review)
                total_count += 1

                # Process when we hit chunk size
                if len(chunk) >= chunk_size:
                    chunk_num += 1
                    valid_reviews = [r for r in chunk if is_valid_review(r)]
                    filtered_reviews.extend(valid_reviews)

                    print(f"  Chunk {chunk_num}: Processed {total_count:,} total | "
                          f"Filtered so far: {len(filtered_reviews):,}")

                    # Clear chunk to free memory
                    chunk = []

                    # Early exit if we have enough
                    if max_filtered and len(filtered_reviews) >= max_filtered:
                        print(f"  Reached target of {max_filtered:,} filtered reviews. Stopping early.")
                        break

            except json.JSONDecodeError:
                total_count += 1
                continue

        # Process any remaining reviews
        if chunk and (not max_filtered or len(filtered_reviews) < max_filtered):
            chunk_num += 1
            valid_reviews = [r for r in chunk if is_valid_review(r)]
            filtered_reviews.extend(valid_reviews)
            print(f"  Chunk {chunk_num}: Processed {total_count:,} total | "
                  f"Filtered so far: {len(filtered_reviews):,}")

    # Convert to DataFrame
    filtered_df = pd.DataFrame(filtered_reviews)
    filtered_count = len(filtered_df)

    print(f"\n{'='*60}")
    print(f"Total reviews scanned: {total_count:,}")
    print(f"Filtered reviews: {filtered_count:,}")
    print(f"Retention rate: {(filtered_count/total_count*100):.2f}%")
    print(f"{'='*60}")

    return filtered_df, total_count, filtered_count

# %% [markdown]
# # Create Balanced Datasets
#
# This section creates balanced datasets with a maximum of 10,000 entries each.

# %%
import re

def preprocess_text(text):
    """
    Clean and normalize text for NLP/LLM models.
    Handles lowercasing, special character removal, and whitespace normalization.
    """
    if not isinstance(text, str):
        return ""

    # Normalize to lowercase
    text = text.lower()

    # Strip out URLs
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)

    # Remove HTML tags
    text = re.sub(r'<[^>]+>', '', text)

    # Keep only alphanumeric characters and basic punctuation
    text = re.sub(r'[^a-z0-9\s.,!?\'\-]', ' ', text)

    # Collapse multiple spaces into one
    text = re.sub(r'\s+', ' ', text)

    # Clean up edges
    text = text.strip()

    return text

def create_balanced_dataset(filtered_df, category_name, dataset_path, max_entries=10000):
    """
    Creates a perfectly balanced dataset with equal representation of all rating classes.
    Preprocesses text, removes duplicates, and ensures exactly max_entries records.
    """
    print(f"\nCreating balanced dataset for {category_name}...")

    # Work with a copy to avoid pandas warnings
    filtered_df = filtered_df.copy()

    # Remove duplicate products (same ASIN)
    print(f"Original filtered dataset: {len(filtered_df):,} entries")
    filtered_df = filtered_df.drop_duplicates(subset=["asin"])
    print(f"After removing duplicate products: {len(filtered_df):,} entries")

    # Clean and normalize all text fields
    print("\nPreprocessing text fields...")
    filtered_df['title'] = filtered_df['title'].apply(preprocess_text)
    filtered_df['text'] = filtered_df['text'].apply(preprocess_text)
    print("Text preprocessing complete")

    # Drop any entries that became empty after preprocessing
    before_cleaning = len(filtered_df)
    filtered_df = filtered_df[
        (filtered_df['title'].str.strip() != '') &
        (filtered_df['text'].str.strip() != '')
    ].copy()
    after_cleaning = len(filtered_df)
    removed = before_cleaning - after_cleaning

    if removed > 0:
        print(f"Removed {removed:,} entries with empty title or text after preprocessing")
    print(f"Entries after text cleaning: {after_cleaning:,}")

    # Shuffle for random sampling
    filtered_df = filtered_df.sample(frac=1, random_state=42).reset_index(drop=True)
    print("Dataset shuffled for random sampling")

    # Calculate how many samples we need per rating
    ratings = sorted(filtered_df["rating"].unique())
    print(f"\nRatings found: {ratings}")

    samples_per_rating = max_entries // len(ratings)
    print(f"Target samples per rating: {samples_per_rating}")
    print(f"Target total entries: {samples_per_rating * len(ratings)}")

    # Sample equally from each rating class
    balanced_samples = []

    for r in ratings:
        subset = filtered_df[filtered_df["rating"] == r]
        available = len(subset)
        to_sample = min(samples_per_rating, available)

        if to_sample < samples_per_rating:
            print(f"  Warning: Rating {r} only has {available:,} samples (need {samples_per_rating:,})")

        if to_sample > 0:
            sampled = subset.sample(n=to_sample, random_state=42)
            balanced_samples.append(sampled)

        print(f"  Rating {r}: {available:,} available, sampled {to_sample:,}")

    # Combine all rating samples
    balanced_df = pd.concat(balanced_samples, ignore_index=True)

    # Shuffle again to mix up the ratings
    balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)
    print(f"\nFinal balanced dataset created: {len(balanced_df):,} entries")

    # Select only the columns we need
    final_df = balanced_df[["rating", "title", "text", "images", "asin", "user_id", "verified_purchase"]].copy()

    # Show final distribution
    print("\nFinal rating distribution:")
    rating_counts = Counter(final_df["rating"])
    for r in sorted(rating_counts.keys()):
        print(f"  Rating {r}: {rating_counts[r]:,}")

    total_final = sum(rating_counts.values())
    print(f"\nTotal entries: {total_final:,}")

    if total_final == max_entries:
        print(f"Success: Exactly {max_entries:,} entries as required")
    else:
        print(f"Warning: Got {total_final:,} entries instead of {max_entries:,}")

    # Show a preview of the cleaned data
    print("\nSample of preprocessed data:")
    sample_row = final_df.iloc[0]
    print(f"  Rating: {sample_row['rating']}")
    print(f"  Title: {sample_row['title'][:80]}...")
    print(f"  Text: {sample_row['text'][:80]}...")

    # Save to CSV
    output_filename = f"{category_name}_balanced.csv"
    output_path = os.path.join(dataset_path, output_filename)
    final_df.to_csv(output_path, index=False)
    print(f"\nSaved balanced dataset to: {output_filename}")
    print("Ready for NLP/LLM processing")

    return output_path

# %% [markdown]
# # Main Execution: Process All Categories
#
# Define the URLs and process each category.

# %%
# Define the URLs for the 5 categories
urls = [
    "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Electronics.jsonl.gz",
    "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Amazon_Fashion.jsonl.gz",
    "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Books.jsonl.gz",
    "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Automotive.jsonl.gz",
    "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Video_Games.jsonl.gz"
]

print(f"Dataset path: {dataset_path}")
print(f"Processing {len(urls)} categories...\n")
# Out:
# Dataset path: /content/gdrive/My Drive/Projects/amazon-reviews/Datasets/
# Processing 5 categories...

# %% [markdown]
# ## Configuration

# %%
# Configuration for processing large datasets
# Adjust based on your Colab tier and available memory

# Number of reviews to process at once (lower = less memory, slower)
CHUNK_SIZE = 100000  # Free tier: 50000-100000, Pro: 200000+

# Max reviews to collect per category before stopping
# Set to None to process entire file (recommended for L4 GPU)
MAX_FILTERED_PER_CATEGORY = None  # Process all data to ensure balanced dataset

# Target size for final balanced dataset
MAX_BALANCED_ENTRIES = 10000

print("Configuration:")
print(f"  Chunk size: {CHUNK_SIZE:,} reviews")
print(f"  Max filtered per category: {'No limit (process entire file)' if MAX_FILTERED_PER_CATEGORY is None else f'{MAX_FILTERED_PER_CATEGORY:,} reviews'}")
print(f"  Max balanced entries: {MAX_BALANCED_ENTRIES:,} reviews")
print("\nNote: Processing entire files to ensure enough samples for rare ratings (2.0, 3.0)")
print("This may take longer but guarantees a truly balanced dataset.")
# Out:
# Configuration:
#   Chunk size: 100,000 reviews
#   Max filtered per category: No limit (process entire file)
#   Max balanced entries: 10,000 reviews
#
# Note: Processing entire files to ensure enough samples for rare ratings (2.0, 3.0)
# This may take longer but guarantees a truly balanced dataset.

# %% [markdown]
# ## Step 1: Download and Extract Files

# %%
# # Download and extract all datasets
# jsonl_paths = []

# for url in urls:
#     jsonl_path = download_and_extract(url, dataset_path)
#     jsonl_paths.append(jsonl_path)

# print(f"\n{'='*60}")
# print(f"All {len(jsonl_paths)} datasets downloaded and extracted")
# print(f"{'='*60}")

# %% [markdown]
# ## Step 2: Filter Reviews and Collect Statistics

# %%
# Process each category and collect statistics
jsonl_paths = [dataset_path+"Amazon_Fashion.jsonl", dataset_path+"Automotive.jsonl", dataset_path+"Books.jsonl", dataset_path+"Electronics.jsonl", dataset_path+"Video_Games.jsonl"]

filtered_data = []
statistics = []

for jsonl_path in jsonl_paths:
    filtered_df, total, filtered = filter_and_count_reviews(
        jsonl_path,
        chunk_size=CHUNK_SIZE,
        max_filtered=MAX_FILTERED_PER_CATEGORY
    )
    category_name = os.path.basename(jsonl_path).replace('.jsonl', '')

    filtered_data.append({
        'category': category_name,
        'df': filtered_df
    })

    statistics.append({
        'Category': category_name,
        'Total Reviews': total,
        'Filtered Reviews': filtered,
        'Retention %': f"{(filtered/total*100):.2f}%"
    })

    # Force garbage collection to free memory
    gc.collect()

# Display summary statistics
print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
stats_df = pd.DataFrame(statistics)
print(stats_df.to_string(index=False))
print("="*80)
# Out:
# ============================================================
# Processing: Amazon_Fashion
# ============================================================
# Loading and filtering reviews in chunks...
#   Chunk 1: Processed 100,000 total | Filtered so far: 4,350
#   Chunk 2: Processed 200,000 total | Filtered so far: 9,537
#   Chunk 3: Processed 300,000 total | Filtered so far: 13,920
#   Chunk 4: Processed 400,000 total | Filtered so far: 18,454
#   Chunk 5: Processed 500,000 total | Filtered so far: 23,422
#   Chunk 6: Processed 600,000 total | Filtered so far: 27,938
#   Chunk 7: Processed 700,000 total | Filtered so far: 32,550
#   Chunk 8: Processed 800,000 total | Filtered so far: 37,138
#   Chunk 9: Processed 900,000 total | Filtered so far: 41,751
#   Chunk 10: Processed 1,000,000 total | Filtered so far: 47,289
#   Chunk 11: Processed 1,100,000 total | Filtered so far: 52,641
#   Chunk 12: Processed 1,200,000 total | Filtered so far: 58,268
#   Chunk 13: Processed 1,300,000 total | Filtered so far: 63,593
#   Chunk 14: Processed 1,400,000 total | Filtered so far: 69,369
#   Chunk 15: Processed 1,500,000 total | Filtered so far: 75,127
#   Chunk 16: Processed 1,600,000 total | Filtered so far: 80,759
#   Chunk 17: Processed 1,700,000 total | Filtered so far: 86,063
#   Chunk 18: Processed 1,800,000 total | Filtered so far: 91,701
#   Chunk 19: Processed 1,900,000 total | Filtered so far: 97,437
#   Chunk 20: Processed 2,000,000 total | Filtered so far: 102,935
#   Chunk 21: Processed 2,100,000 total | Filtered so far: 108,608
#   Chunk 22: Processed 2,200,000 total | Filtered so far: 114,482
#   Chunk 23: Processed 2,300,000 total | Filtered so far: 121,284
#   Chunk 24: Processed 2,400,000 total | Filtered so far: 127,582
#   Chunk 25: Processed 2,500,000 total | Filtered so far: 133,922
#   Chunk 26: Processed 2,500,939 total | Filtered so far: 133,984
#
# ============================================================
# Total reviews scanned: 2,500,939
# Filtered reviews: 133,984
# Retention rate: 5.36%
# ============================================================
#
# ============================================================
# Processing: Automotive
# ============================================================
# Loading and filtering reviews in chunks...
#   Chunk 1: Processed 100,000 total | Filtered so far: 3,763
#   Chunk 2: Processed 200,000 total | Filtered so far: 8,087
#   Chunk 3: Processed 300,000 total | Filtered so far: 12,533
#   Chunk 4: Processed 400,000 total | Filtered so far: 16,823
#   Chunk 5: Processed 500,000 total | Filtered so far: 21,303
#   Chunk 6: Processed 600,000 total | Filtered so far: 26,422
#   Chunk 7: Processed 700,000 total | Filtered so far: 30,404
#   Chunk 8: Processed 800,000 total | Filtered so far: 35,197
#   Chunk 9: Processed 900,000 total | Filtered so far: 39,863
#   Chunk 10: Processed 1,000,000 total | Filtered so far: 44,118
#   Chunk 11: Processed 1,100,000 total | Filtered so far: 48,970
#   Chunk 12: Processed 1,200,000 total | Filtered so far: 53,620
#   Chunk 13: Processed 1,300,000 total | Filtered so far: 57,569
#   Chunk 14: Processed 1,400,000 total | Filtered so far: 62,771
#   Chunk 15: Processed 1,500,000 total | Filtered so far: 67,077
#   Chunk 16: Processed 1,600,000 total | Filtered so far: 71,153
#   Chunk 17: Processed 1,700,000 total | Filtered so far: 75,358
#   Chunk 18: Processed 1,800,000 total | Filtered so far: 80,088
#   Chunk 19: Processed 1,900,000 total | Filtered so far: 84,651
#   Chunk 20: Processed 2,000,000 total | Filtered so far: 89,164
#   Chunk 21: Processed 2,100,000 total | Filtered so far: 94,917
#   Chunk 22: Processed 2,200,000 total | Filtered so far: 99,285
#   Chunk 23: Processed 2,300,000 total | Filtered so far: 103,656
#   Chunk 24: Processed 2,400,000 total | Filtered so far: 110,674
#   Chunk 25: Processed 2,500,000 total | Filtered so far: 114,525
#   Chunk 26: Processed 2,600,000 total | Filtered so far: 118,780
#   Chunk 27: Processed 2,700,000 total | Filtered so far: 123,168
#   Chunk 28: Processed 2,800,000 total | Filtered so far: 127,459
#   Chunk 29: Processed 2,900,000 total | Filtered so far: 132,423
#   Chunk 30: Processed 3,000,000 total | Filtered so far: 136,529
#   Chunk 31: Processed 3,100,000 total | Filtered so far: 140,767
#   Chunk 32: Processed 3,200,000 total | Filtered so far: 145,342
#   Chunk 33: Processed 3,300,000 total | Filtered so far: 149,871
#   Chunk 34: Processed 3,400,000 total | Filtered so far: 153,985
#   Chunk 35: Processed 3,500,000 total | Filtered so far: 157,878
#   Chunk 36: Processed 3,600,000 total | Filtered so far: 162,439
#   Chunk 37: Processed 3,700,000 total | Filtered so far: 167,228
#   Chunk 38: Processed 3,800,000 total | Filtered so far: 171,944
#   Chunk 39: Processed 3,900,000 total | Filtered so far: 177,065
#   Chunk 40: Processed 4,000,000 total | Filtered so far: 182,095
#   Chunk 41: Processed 4,100,000 total | Filtered so far: 187,031
#   Chunk 42: Processed 4,200,000 total | Filtered so far: 192,042
#   Chunk 43: Processed 4,300,000 total | Filtered so far: 197,013
#   Chunk 44: Processed 4,400,000 total | Filtered so far: 200,968
#   Chunk 45: Processed 4,500,000 total | Filtered so far: 204,626
#   Chunk 46: Processed 4,600,000 total | Filtered so far: 208,968
#   Chunk 47: Processed 4,700,000 total | Filtered so far: 213,229
#   Chunk 48: Processed 4,800,000 total | Filtered so far: 218,047
#   Chunk 49: Processed 4,900,000 total | Filtered so far: 222,651
#   Chunk 50: Processed 5,000,000 total | Filtered so far: 227,122
#   Chunk 51: Processed 5,100,000 total | Filtered so far: 231,414
#   Chunk 52: Processed 5,200,000 total | Filtered so far: 235,797
#   Chunk 53: Processed 5,300,000 total | Filtered so far: 240,368
#   Chunk 54: Processed 5,400,000 total | Filtered so far: 245,149
#   Chunk 55: Processed 5,500,000 total | Filtered so far: 249,858
#   Chunk 56: Processed 5,600,000 total | Filtered so far: 254,636
#   Chunk 57: Processed 5,700,000 total | Filtered so far: 259,759
#   Chunk 58: Processed 5,800,000 total | Filtered so far: 264,388
#   Chunk 59: Processed 5,900,000 total | Filtered so far: 268,990
#   Chunk 60: Processed 6,000,000 total | Filtered so far: 273,776
#   Chunk 61: Processed 6,100,000 total | Filtered so far: 278,399
#   Chunk 62: Processed 6,200,000 total | Filtered so far: 282,785
#   Chunk 63: Processed 6,300,000 total | Filtered so far: 287,660
#   Chunk 64: Processed 6,400,000 total | Filtered so far: 292,952
#   Chunk 65: Processed 6,500,000 total | Filtered so far: 298,064
#   Chunk 66: Processed 6,600,000 total | Filtered so far: 304,124
#   Chunk 67: Processed 6,700,000 total | Filtered so far: 310,055
#   Chunk 68: Processed 6,800,000 total | Filtered so far: 314,970
#   Chunk 69: Processed 6,900,000 total | Filtered so far: 320,216
#   Chunk 70: Processed 7,000,000 total | Filtered so far: 325,373
#   Chunk 71: Processed 7,100,000 total | Filtered so far: 329,632
#   Chunk 72: Processed 7,200,000 total | Filtered so far: 334,441
#   Chunk 73: Processed 7,300,000 total | Filtered so far: 340,028
#   Chunk 74: Processed 7,400,000 total | Filtered so far: 345,478
#   Chunk 75: Processed 7,500,000 total | Filtered so far: 351,656
#   Chunk 76: Processed 7,600,000 total | Filtered so far: 357,049
#   Chunk 77: Processed 7,700,000 total | Filtered so far: 362,212
#   Chunk 78: Processed 7,800,000 total | Filtered so far: 367,349
#   Chunk 79: Processed 7,900,000 total | Filtered so far: 372,607
#   Chunk 80: Processed 8,000,000 total | Filtered so far: 378,451
#   Chunk 81: Processed 8,100,000 total | Filtered so far: 383,683
#   Chunk 82: Processed 8,200,000 total | Filtered so far: 389,045
#   Chunk 83: Processed 8,300,000 total | Filtered so far: 394,308
#   Chunk 84: Processed 8,400,000 total | Filtered so far: 400,110
#   Chunk 85: Processed 8,500,000 total | Filtered so far: 405,520
#   Chunk 86: Processed 8,600,000 total | Filtered so far: 410,603
#   Chunk 87: Processed 8,700,000 total | Filtered so far: 416,272
#   Chunk 88: Processed 8,800,000 total | Filtered so far: 421,793
#   Chunk 89: Processed 8,900,000 total | Filtered so far: 427,583
#   Chunk 90: Processed 9,000,000 total | Filtered so far: 433,455
#   Chunk 91: Processed 9,100,000 total | Filtered so far: 438,886
#   Chunk 92: Processed 9,200,000 total | Filtered so far: 444,497
#   Chunk 93: Processed 9,300,000 total | Filtered so far: 450,194
#   Chunk 94: Processed 9,400,000 total | Filtered so far: 455,534
#   Chunk 95: Processed 9,500,000 total | Filtered so far: 460,858
#   Chunk 96: Processed 9,600,000 total | Filtered so far: 466,750
#   Chunk 97: Processed 9,700,000 total | Filtered so far: 472,370
#   Chunk 98: Processed 9,800,000 total | Filtered so far: 478,192
#   Chunk 99: Processed 9,900,000 total | Filtered so far: 484,728
#   Chunk 100: Processed 10,000,000 total | Filtered so far: 490,440
#   Chunk 101: Processed 10,100,000 total | Filtered so far: 496,033
#   Chunk 102: Processed 10,200,000 total | Filtered so far: 501,769
#   Chunk 103: Processed 10,300,000 total | Filtered so far: 507,446
#   Chunk 104: Processed 10,400,000 total | Filtered so far: 512,625
#   Chunk 105: Processed 10,500,000 total | Filtered so far: 518,357
#   Chunk 106: Processed 10,600,000 total | Filtered so far: 523,605
#   Chunk 107: Processed 10,700,000 total | Filtered so far: 529,110
#   Chunk 108: Processed 10,800,000 total | Filtered so far: 535,091
#   Chunk 109: Processed 10,900,000 total | Filtered so far: 540,789
#   Chunk 110: Processed 11,000,000 total | Filtered so far: 546,085
#   Chunk 111: Processed 11,100,000 total | Filtered so far: 551,535
#   Chunk 112: Processed 11,200,000 total | Filtered so far: 557,191
#   Chunk 113: Processed 11,300,000 total | Filtered so far: 563,715
#   Chunk 114: Processed 11,400,000 total | Filtered so far: 569,665
#   Chunk 115: Processed 11,500,000 total | Filtered so far: 575,336
#   Chunk 116: Processed 11,600,000 total | Filtered so far: 580,567
#   Chunk 117: Processed 11,700,000 total | Filtered so far: 586,344
#   Chunk 118: Processed 11,800,000 total | Filtered so far: 592,304
#   Chunk 119: Processed 11,900,000 total | Filtered so far: 597,917
#   Chunk 120: Processed 12,000,000 total | Filtered so far: 603,440
#   Chunk 121: Processed 12,100,000 total | Filtered so far: 609,116
#   Chunk 122: Processed 12,200,000 total | Filtered so far: 615,167
#   Chunk 123: Processed 12,300,000 total | Filtered so far: 620,994
#   Chunk 124: Processed 12,400,000 total | Filtered so far: 627,404
#   Chunk 125: Processed 12,500,000 total | Filtered so far: 632,531
#   Chunk 126: Processed 12,600,000 total | Filtered so far: 638,386
#   Chunk 127: Processed 12,700,000 total | Filtered so far: 644,091
#   Chunk 128: Processed 12,800,000 total | Filtered so far: 650,503
#   Chunk 129: Processed 12,900,000 total | Filtered so far: 656,637
#   Chunk 130: Processed 13,000,000 total | Filtered so far: 662,302
#   Chunk 131: Processed 13,100,000 total | Filtered so far: 668,224
#   Chunk 132: Processed 13,200,000 total | Filtered so far: 674,011
#   Chunk 133: Processed 13,300,000 total | Filtered so far: 680,609
#   Chunk 134: Processed 13,400,000 total | Filtered so far: 686,750
#   Chunk 135: Processed 13,500,000 total | Filtered so far: 693,290
#   Chunk 136: Processed 13,600,000 total | Filtered so far: 699,237
#   Chunk 137: Processed 13,700,000 total | Filtered so far: 704,987
#   Chunk 138: Processed 13,800,000 total | Filtered so far: 711,337
#   Chunk 139: Processed 13,900,000 total | Filtered so far: 717,129
#   Chunk 140: Processed 14,000,000 total | Filtered so far: 722,691
#   Chunk 141: Processed 14,100,000 total | Filtered so far: 729,420
#   Chunk 142: Processed 14,200,000 total | Filtered so far: 735,157
#   Chunk 143: Processed 14,300,000 total | Filtered so far: 741,394
#   Chunk 144: Processed 14,400,000 total | Filtered so far: 747,076
#   Chunk 145: Processed 14,500,000 total | Filtered so far: 753,169
#   Chunk 146: Processed 14,600,000 total | Filtered so far: 759,044
#   Chunk 147: Processed 14,700,000 total | Filtered so far: 764,792
#   Chunk 148: Processed 14,800,000 total | Filtered so far: 770,404
#   Chunk 149: Processed 14,900,000 total | Filtered so far: 776,482
#   Chunk 150: Processed 15,000,000 total | Filtered so far: 782,639
#   Chunk 151: Processed 15,100,000 total | Filtered so far: 788,536
#   Chunk 152: Processed 15,200,000 total | Filtered so far: 794,368
#   Chunk 153: Processed 15,300,000 total | Filtered so far: 800,455
#   Chunk 154: Processed 15,400,000 total | Filtered so far: 806,394
#   Chunk 155: Processed 15,500,000 total | Filtered so far: 812,750
#   Chunk 156: Processed 15,600,000 total | Filtered so far: 818,783
#   Chunk 157: Processed 15,700,000 total | Filtered so far: 825,217
#   Chunk 158: Processed 15,800,000 total | Filtered so far: 831,235
#   Chunk 159: Processed 15,900,000 total | Filtered so far: 837,460
#   Chunk 160: Processed 16,000,000 total | Filtered so far: 843,964
#   Chunk 161: Processed 16,100,000 total | Filtered so far: 850,629
#   Chunk 162: Processed 16,200,000 total | Filtered so far: 857,327
#   Chunk 163: Processed 16,300,000 total | Filtered so far: 863,559
#   Chunk 164: Processed 16,400,000 total | Filtered so far: 870,291
#   Chunk 165: Processed 16,500,000 total | Filtered so far: 877,025
#   Chunk 166: Processed 16,600,000 total | Filtered so far: 883,845
#   Chunk 167: Processed 16,700,000 total | Filtered so far: 891,010
#   Chunk 168: Processed 16,800,000 total | Filtered so far: 898,624
#   Chunk 169: Processed 16,900,000 total | Filtered so far: 905,849
#   Chunk 170: Processed 17,000,000 total | Filtered so far: 912,854
#   Chunk 171: Processed 17,100,000 total | Filtered so far: 919,553
#   Chunk 172: Processed 17,200,000 total | Filtered so far: 927,035
#   Chunk 173: Processed 17,300,000 total | Filtered so far: 934,431
#   Chunk 174: Processed 17,400,000 total | Filtered so far: 941,896
#   Chunk 175: Processed 17,500,000 total | Filtered so far: 948,975
#   Chunk 176: Processed 17,600,000 total | Filtered so far: 955,417
#   Chunk 177: Processed 17,700,000 total | Filtered so far: 962,778
#   Chunk 178: Processed 17,800,000 total | Filtered so far: 969,118
#   Chunk 179: Processed 17,900,000 total | Filtered so far: 975,638
#   Chunk 180: Processed 18,000,000 total | Filtered so far: 982,687
#   Chunk 181: Processed 18,100,000 total | Filtered so far: 989,648
#   Chunk 182: Processed 18,200,000 total | Filtered so far: 996,678
#   Chunk 183: Processed 18,300,000 total | Filtered so far: 1,004,004
#   Chunk 184: Processed 18,400,000 total | Filtered so far: 1,011,071
#   Chunk 185: Processed 18,500,000 total | Filtered so far: 1,018,042
#   Chunk 186: Processed 18,600,000 total | Filtered so far: 1,024,868
#   Chunk 187: Processed 18,700,000 total | Filtered so far: 1,031,968
#   Chunk 188: Processed 18,800,000 total | Filtered so far: 1,038,890
#   Chunk 189: Processed 18,900,000 total | Filtered so far: 1,046,544
#   Chunk 190: Processed 19,000,000 total | Filtered so far: 1,054,095
#   Chunk 191: Processed 19,100,000 total | Filtered so far: 1,061,809
#   Chunk 192: Processed 19,200,000 total | Filtered so far: 1,068,712
#   Chunk 193: Processed 19,300,000 total | Filtered so far: 1,075,649
#   Chunk 194: Processed 19,400,000 total | Filtered so far: 1,083,235
#   Chunk 195: Processed 19,500,000 total | Filtered so far: 1,090,306
#   Chunk 196: Processed 19,600,000 total | Filtered so far: 1,097,557
#   Chunk 197: Processed 19,700,000 total | Filtered so far: 1,104,679
#   Chunk 198: Processed 19,800,000 total | Filtered so far: 1,112,732
#   Chunk 199: Processed 19,900,000 total | Filtered so far: 1,119,922
#   Chunk 200: Processed 19,955,450 total | Filtered so far: 1,123,953
#
# ============================================================
# Total reviews scanned: 19,955,450
# Filtered reviews: 1,123,953
# Retention rate: 5.63%
# ============================================================
#
# ============================================================
# Processing: Books
# ============================================================
# Loading and filtering reviews in chunks...
#   Chunk 1: Processed 100,000 total | Filtered so far: 901
#   Chunk 2: Processed 200,000 total | Filtered so far: 1,777
#   Chunk 3: Processed 300,000 total | Filtered so far: 2,506
#   Chunk 4: Processed 400,000 total | Filtered so far: 3,956
#   Chunk 5: Processed 500,000 total | Filtered so far: 4,774
#   Chunk 6: Processed 600,000 total | Filtered so far: 5,637
#   Chunk 7: Processed 700,000 total | Filtered so far: 6,456
#   Chunk 8: Processed 800,000 total | Filtered so far: 7,321
#   Chunk 9: Processed 900,000 total | Filtered so far: 8,267
#   Chunk 10: Processed 1,000,000 total | Filtered so far: 9,209
#   Chunk 11: Processed 1,100,000 total | Filtered so far: 10,128
#   Chunk 12: Processed 1,200,000 total | Filtered so far: 10,928
#   Chunk 13: Processed 1,300,000 total | Filtered so far: 12,168
#   Chunk 14: Processed 1,400,000 total | Filtered so far: 13,064
#   Chunk 15: Processed 1,500,000 total | Filtered so far: 14,319
#   Chunk 16: Processed 1,600,000 total | Filtered so far: 15,368
#   Chunk 17: Processed 1,700,000 total | Filtered so far: 16,763
#   Chunk 18: Processed 1,800,000 total | Filtered so far: 17,886
#   Chunk 19: Processed 1,900,000 total | Filtered so far: 18,591
#   Chunk 20: Processed 2,000,000 total | Filtered so far: 19,295
#   Chunk 21: Processed 2,100,000 total | Filtered so far: 20,225
#   Chunk 22: Processed 2,200,000 total | Filtered so far: 20,996
#   Chunk 23: Processed 2,300,000 total | Filtered so far: 21,973
#   Chunk 24: Processed 2,400,000 total | Filtered so far: 22,581
#   Chunk 25: Processed 2,500,000 total | Filtered so far: 23,133
#   Chunk 26: Processed 2,600,000 total | Filtered so far: 23,497
#   Chunk 27: Processed 2,700,000 total | Filtered so far: 24,144
#   Chunk 28: Processed 2,800,000 total | Filtered so far: 25,220
#   Chunk 29: Processed 2,900,000 total | Filtered so far: 26,086
#   Chunk 30: Processed 3,000,000 total | Filtered so far: 26,936
#   Chunk 31: Processed 3,100,000 total | Filtered so far: 28,227
#   Chunk 32: Processed 3,200,000 total | Filtered so far: 29,432
#   Chunk 33: Processed 3,300,000 total | Filtered so far: 30,370
#   Chunk 34: Processed 3,400,000 total | Filtered so far: 31,217
#   Chunk 35: Processed 3,500,000 total | Filtered so far: 32,163
#   Chunk 36: Processed 3,600,000 total | Filtered so far: 33,312
#   Chunk 37: Processed 3,700,000 total | Filtered so far: 34,199
#   Chunk 38: Processed 3,800,000 total | Filtered so far: 35,042
#   Chunk 39: Processed 3,900,000 total | Filtered so far: 36,022
#   Chunk 40: Processed 4,000,000 total | Filtered so far: 36,909
#   Chunk 41: Processed 4,100,000 total | Filtered so far: 37,213
#   Chunk 42: Processed 4,200,000 total | Filtered so far: 37,807
#   Chunk 43: Processed 4,300,000 total | Filtered so far: 38,424
#   Chunk 44: Processed 4,400,000 total | Filtered so far: 39,324
#   Chunk 45: Processed 4,500,000 total | Filtered so far: 40,587
#   Chunk 46: Processed 4,600,000 total | Filtered so far: 41,242
#   Chunk 47: Processed 4,700,000 total | Filtered so far: 42,006
#   Chunk 48: Processed 4,800,000 total | Filtered so far: 42,806
#   Chunk 49: Processed 4,900,000 total | Filtered so far: 43,555
#   Chunk 50: Processed 5,000,000 total | Filtered so far: 44,326
#   Chunk 51: Processed 5,100,000 total | Filtered so far: 45,198
#   Chunk 52: Processed 5,200,000 total | Filtered so far: 45,948
#   Chunk 53: Processed 5,300,000 total | Filtered so far: 46,490
#   Chunk 54: Processed 5,400,000 total | Filtered so far: 46,910
#   Chunk 55: Processed 5,500,000 total | Filtered so far: 47,329
#   Chunk 56: Processed 5,600,000 total | Filtered so far: 47,816
#   Chunk 57: Processed 5,700,000 total | Filtered so far: 48,181
#   Chunk 58: Processed 5,800,000 total | Filtered so far: 48,498
#   Chunk 59: Processed 5,900,000 total | Filtered so far: 49,434
#   Chunk 60: Processed 6,000,000 total | Filtered so far: 49,956
#   Chunk 61: Processed 6,100,000 total | Filtered so far: 50,513
#   Chunk 62: Processed 6,200,000 total | Filtered so far: 51,494
#   Chunk 63: Processed 6,300,000 total | Filtered so far: 52,430
#   Chunk 64: Processed 6,400,000 total | Filtered so far: 53,306
#   Chunk 65: Processed 6,500,000 total | Filtered so far: 54,305
#   Chunk 66: Processed 6,600,000 total | Filtered so far: 55,275
#   Chunk 67: Processed 6,700,000 total | Filtered so far: 56,325
#   Chunk 68: Processed 6,800,000 total | Filtered so far: 57,527
#   Chunk 69: Processed 6,900,000 total | Filtered so far: 58,708
#   Chunk 70: Processed 7,000,000 total | Filtered so far: 59,700
#   Chunk 71: Processed 7,100,000 total | Filtered so far: 60,383
#   Chunk 72: Processed 7,200,000 total | Filtered so far: 61,092
#   Chunk 73: Processed 7,300,000 total | Filtered so far: 61,780
#   Chunk 74: Processed 7,400,000 total | Filtered so far: 62,505
#   Chunk 75: Processed 7,500,000 total | Filtered so far: 63,494
#   Chunk 76: Processed 7,600,000 total | Filtered so far: 64,540
#   Chunk 77: Processed 7,700,000 total | Filtered so far: 65,325
#   Chunk 78: Processed 7,800,000 total | Filtered so far: 66,174
#   Chunk 79: Processed 7,900,000 total | Filtered so far: 66,964
#   Chunk 80: Processed 8,000,000 total | Filtered so far: 67,869
#   Chunk 81: Processed 8,100,000 total | Filtered so far: 68,741
#   Chunk 82: Processed 8,200,000 total | Filtered so far: 69,446
#   Chunk 83: Processed 8,300,000 total | Filtered so far: 70,265
#   Chunk 84: Processed 8,400,000 total | Filtered so far: 71,011
#   Chunk 85: Processed 8,500,000 total | Filtered so far: 72,152
#   Chunk 86: Processed 8,600,000 total | Filtered so far: 73,039
#   Chunk 87: Processed 8,700,000 total | Filtered so far: 73,898
#   Chunk 88: Processed 8,800,000 total | Filtered so far: 74,819
#   Chunk 89: Processed 8,900,000 total | Filtered so far: 75,676
#   Chunk 90: Processed 9,000,000 total | Filtered so far: 76,283
#   Chunk 91: Processed 9,100,000 total | Filtered so far: 77,019
#   Chunk 92: Processed 9,200,000 total | Filtered so far: 77,913
#   Chunk 93: Processed 9,300,000 total | Filtered so far: 78,899
#   Chunk 94: Processed 9,400,000 total | Filtered so far: 79,742
#   Chunk 95: Processed 9,500,000 total | Filtered so far: 80,769
#   Chunk 96: Processed 9,600,000 total | Filtered so far: 81,644
#   Chunk 97: Processed 9,700,000 total | Filtered so far: 82,632
#   Chunk 98: Processed 9,800,000 total | Filtered so far: 83,393
#   Chunk 99: Processed 9,900,000 total | Filtered so far: 84,209
#   Chunk 100: Processed 10,000,000 total | Filtered so far: 85,329
#   Chunk 101: Processed 10,100,000 total | Filtered so far: 86,771
#   Chunk 102: Processed 10,200,000 total | Filtered so far: 87,846
#   Chunk 103: Processed 10,300,000 total | Filtered so far: 89,126
#   Chunk 104: Processed 10,400,000 total | Filtered so far: 90,576
#   Chunk 105: Processed 10,500,000 total | Filtered so far: 91,369
#   Chunk 106: Processed 10,600,000 total | Filtered so far: 92,431
#   Chunk 107: Processed 10,700,000 total | Filtered so far: 93,379
#   Chunk 108: Processed 10,800,000 total | Filtered so far: 94,594
#   Chunk 109: Processed 10,900,000 total | Filtered so far: 95,574
#   Chunk 110: Processed 11,000,000 total | Filtered so far: 96,291
#   Chunk 111: Processed 11,100,000 total | Filtered so far: 97,000
#   Chunk 112: Processed 11,200,000 total | Filtered so far: 97,855
#   Chunk 113: Processed 11,300,000 total | Filtered so far: 98,766
#   Chunk 114: Processed 11,400,000 total | Filtered so far: 99,413
#   Chunk 115: Processed 11,500,000 total | Filtered so far: 100,688
#   Chunk 116: Processed 11,600,000 total | Filtered so far: 102,241
#   Chunk 117: Processed 11,700,000 total | Filtered so far: 103,540
#   Chunk 118: Processed 11,800,000 total | Filtered so far: 104,822
#   Chunk 119: Processed 11,900,000 total | Filtered so far: 105,658
#   Chunk 120: Processed 12,000,000 total | Filtered so far: 106,548
#   Chunk 121: Processed 12,100,000 total | Filtered so far: 106,881
#   Chunk 122: Processed 12,200,000 total | Filtered so far: 107,527
#   Chunk 123: Processed 12,300,000 total | Filtered so far: 107,976
#   Chunk 124: Processed 12,400,000 total | Filtered so far: 109,329
#   Chunk 125: Processed 12,500,000 total | Filtered so far: 110,406
#   Chunk 126: Processed 12,600,000 total | Filtered so far: 111,783
#   Chunk 127: Processed 12,700,000 total | Filtered so far: 112,886
#   Chunk 128: Processed 12,800,000 total | Filtered so far: 113,632
#   Chunk 129: Processed 12,900,000 total | Filtered so far: 114,239
#   Chunk 130: Processed 13,000,000 total | Filtered so far: 115,322
#   Chunk 131: Processed 13,100,000 total | Filtered so far: 116,389
#   Chunk 132: Processed 13,200,000 total | Filtered so far: 117,184
#   Chunk 133: Processed 13,300,000 total | Filtered so far: 117,768
#   Chunk 134: Processed 13,400,000 total | Filtered so far: 118,203
#   Chunk 135: Processed 13,500,000 total | Filtered so far: 118,586
#   Chunk 136: Processed 13,600,000 total | Filtered so far: 118,874
#   Chunk 137: Processed 13,700,000 total | Filtered so far: 119,370
#   Chunk 138: Processed 13,800,000 total | Filtered so far: 119,754
#   Chunk 139: Processed 13,900,000 total | Filtered so far: 120,478
#   Chunk 140: Processed 14,000,000 total | Filtered so far: 121,630
#   Chunk 141: Processed 14,100,000 total | Filtered so far: 122,809
#   Chunk 142: Processed 14,200,000 total | Filtered so far: 124,238
#   Chunk 143: Processed 14,300,000 total | Filtered so far: 125,317
#   Chunk 144: Processed 14,400,000 total | Filtered so far: 126,489
#   Chunk 145: Processed 14,500,000 total | Filtered so far: 127,189
#   Chunk 146: Processed 14,600,000 total | Filtered so far: 128,244
#   Chunk 147: Processed 14,700,000 total | Filtered so far: 129,323
#   Chunk 148: Processed 14,800,000 total | Filtered so far: 130,583
#   Chunk 149: Processed 14,900,000 total | Filtered so far: 131,542
#   Chunk 150: Processed 15,000,000 total | Filtered so far: 132,792
#   Chunk 151: Processed 15,100,000 total | Filtered so far: 133,948
#   Chunk 152: Processed 15,200,000 total | Filtered so far: 134,860
#   Chunk 153: Processed 15,300,000 total | Filtered so far: 136,142
#   Chunk 154: Processed 15,400,000 total | Filtered so far: 137,106
#   Chunk 155: Processed 15,500,000 total | Filtered so far: 138,348
#   Chunk 156: Processed 15,600,000 total | Filtered so far: 139,517
#   Chunk 157: Processed 15,700,000 total | Filtered so far: 140,728
#   Chunk 158: Processed 15,800,000 total | Filtered so far: 141,415
#   Chunk 159: Processed 15,900,000 total | Filtered so far: 142,952
#   Chunk 160: Processed 16,000,000 total | Filtered so far: 143,833
#   Chunk 161: Processed 16,100,000 total | Filtered so far: 144,676
#   Chunk 162: Processed 16,200,000 total | Filtered so far: 145,233
#   Chunk 163: Processed 16,300,000 total | Filtered so far: 146,345
#   Chunk 164: Processed 16,400,000 total | Filtered so far: 147,208
#   Chunk 165: Processed 16,500,000 total | Filtered so far: 147,984
#   Chunk 166: Processed 16,600,000 total | Filtered so far: 149,198
#   Chunk 167: Processed 16,700,000 total | Filtered so far: 150,057
#   Chunk 168: Processed 16,800,000 total | Filtered so far: 151,071
#   Chunk 169: Processed 16,900,000 total | Filtered so far: 152,267
#   Chunk 170: Processed 17,000,000 total | Filtered so far: 153,422
#   Chunk 171: Processed 17,100,000 total | Filtered so far: 154,488
#   Chunk 172: Processed 17,200,000 total | Filtered so far: 155,728
#   Chunk 173: Processed 17,300,000 total | Filtered so far: 156,671
#   Chunk 174: Processed 17,400,000 total | Filtered so far: 157,680
#   Chunk 175: Processed 17,500,000 total | Filtered so far: 158,603
#   Chunk 176: Processed 17,600,000 total | Filtered so far: 160,047
#   Chunk 177: Processed 17,700,000 total | Filtered so far: 161,054
#   Chunk 178: Processed 17,800,000 total | Filtered so far: 161,692
#   Chunk 179: Processed 17,900,000 total | Filtered so far: 162,907
#   Chunk 180: Processed 18,000,000 total | Filtered so far: 163,443
#   Chunk 181: Processed 18,100,000 total | Filtered so far: 164,068
#   Chunk 182: Processed 18,200,000 total | Filtered so far: 165,106
#   Chunk 183: Processed 18,300,000 total | Filtered so far: 165,472
#   Chunk 184: Processed 18,400,000 total | Filtered so far: 165,988
#   Chunk 185: Processed 18,500,000 total | Filtered so far: 166,993
#   Chunk 186: Processed 18,600,000 total | Filtered so far: 167,754
#   Chunk 187: Processed 18,700,000 total | Filtered so far: 168,329
#   Chunk 188: Processed 18,800,000 total | Filtered so far: 168,869
#   Chunk 189: Processed 18,900,000 total | Filtered so far: 169,956
#   Chunk 190: Processed 19,000,000 total | Filtered so far: 170,939
#   Chunk 191: Processed 19,100,000 total | Filtered so far: 172,086
#   Chunk 192: Processed 19,200,000 total | Filtered so far: 173,104
#   Chunk 193: Processed 19,300,000 total | Filtered so far: 174,239
#   Chunk 194: Processed 19,400,000 total | Filtered so far: 175,610
#   Chunk 195: Processed 19,500,000 total | Filtered so far: 176,908
#   Chunk 196: Processed 19,600,000 total | Filtered so far: 178,014
#   Chunk 197: Processed 19,700,000 total | Filtered so far: 178,861
#   Chunk 198: Processed 19,800,000 total | Filtered so far: 179,958
#   Chunk 199: Processed 19,900,000 total | Filtered so far: 181,117
#   Chunk 200: Processed 20,000,000 total | Filtered so far: 182,295
#   Chunk 201: Processed 20,100,000 total | Filtered so far: 183,866
#   Chunk 202: Processed 20,200,000 total | Filtered so far: 184,806
#   Chunk 203: Processed 20,300,000 total | Filtered so far: 185,964
#   Chunk 204: Processed 20,400,000 total | Filtered so far: 186,798
#   Chunk 205: Processed 20,500,000 total | Filtered so far: 187,169
#   Chunk 206: Processed 20,600,000 total | Filtered so far: 187,594
#   Chunk 207: Processed 20,700,000 total | Filtered so far: 188,932
#   Chunk 208: Processed 20,800,000 total | Filtered so far: 190,005
#   Chunk 209: Processed 20,900,000 total | Filtered so far: 190,514
#   Chunk 210: Processed 21,000,000 total | Filtered so far: 191,520
#   Chunk 211: Processed 21,100,000 total | Filtered so far: 192,539
#   Chunk 212: Processed 21,200,000 total | Filtered so far: 194,126
#   Chunk 213: Processed 21,300,000 total | Filtered so far: 195,075
#   Chunk 214: Processed 21,400,000 total | Filtered so far: 196,559
#   Chunk 215: Processed 21,500,000 total | Filtered so far: 197,966
#   Chunk 216: Processed 21,600,000 total | Filtered so far: 199,037
#   Chunk 217: Processed 21,700,000 total | Filtered so far: 200,441
#   Chunk 218: Processed 21,800,000 total | Filtered so far: 201,368
#   Chunk 219: Processed 21,900,000 total | Filtered so far: 202,292
#   Chunk 220: Processed 22,000,000 total | Filtered so far: 203,169
#   Chunk 221: Processed 22,100,000 total | Filtered so far: 204,399
#   Chunk 222: Processed 22,200,000 total | Filtered so far: 205,500
#   Chunk 223: Processed 22,300,000 total | Filtered so far: 206,816
#   Chunk 224: Processed 22,400,000 total | Filtered so far: 207,708
#   Chunk 225: Processed 22,500,000 total | Filtered so far: 208,873
#   Chunk 226: Processed 22,600,000 total | Filtered so far: 210,025
#   Chunk 227: Processed 22,700,000 total | Filtered so far: 211,214
#   Chunk 228: Processed 22,800,000 total | Filtered so far: 212,525
#   Chunk 229: Processed 22,900,000 total | Filtered so far: 213,690
#   Chunk 230: Processed 23,000,000 total | Filtered so far: 214,730
#   Chunk 231: Processed 23,100,000 total | Filtered so far: 215,981
#   Chunk 232: Processed 23,200,000 total | Filtered so far: 216,936
#   Chunk 233: Processed 23,300,000 total | Filtered so far: 218,129
#   Chunk 234: Processed 23,400,000 total | Filtered so far: 219,358
#   Chunk 235: Processed 23,500,000 total | Filtered so far: 220,448
#   Chunk 236: Processed 23,600,000 total | Filtered so far: 221,480
#   Chunk 237: Processed 23,700,000 total | Filtered so far: 222,591
#   Chunk 238: Processed 23,800,000 total | Filtered so far: 223,241
#   Chunk 239: Processed 23,900,000 total | Filtered so far: 224,253
#   Chunk 240: Processed 24,000,000 total | Filtered so far: 225,387
#   Chunk 241: Processed 24,100,000 total | Filtered so far: 226,573
#   Chunk 242: Processed 24,200,000 total | Filtered so far: 228,043
#   Chunk 243: Processed 24,300,000 total | Filtered so far: 229,275
#   Chunk 244: Processed 24,400,000 total | Filtered so far: 230,497
#   Chunk 245: Processed 24,500,000 total | Filtered so far: 231,829
#   Chunk 246: Processed 24,600,000 total | Filtered so far: 232,802
#   Chunk 247: Processed 24,700,000 total | Filtered so far: 233,815
#   Chunk 248: Processed 24,800,000 total | Filtered so far: 234,577
#   Chunk 249: Processed 24,900,000 total | Filtered so far: 235,865
#   Chunk 250: Processed 25,000,000 total | Filtered so far: 237,119
#   Chunk 251: Processed 25,100,000 total | Filtered so far: 238,507
#   Chunk 252: Processed 25,200,000 total | Filtered so far: 240,134
#   Chunk 253: Processed 25,300,000 total | Filtered so far: 241,698
#   Chunk 254: Processed 25,400,000 total | Filtered so far: 243,708
#   Chunk 255: Processed 25,500,000 total | Filtered so far: 245,585
#   Chunk 256: Processed 25,600,000 total | Filtered so far: 246,871
#   Chunk 257: Processed 25,700,000 total | Filtered so far: 248,022
#   Chunk 258: Processed 25,800,000 total | Filtered so far: 249,167
#   Chunk 259: Processed 25,900,000 total | Filtered so far: 250,638
#   Chunk 260: Processed 26,000,000 total | Filtered so far: 252,178
#   Chunk 261: Processed 26,100,000 total | Filtered so far: 253,610
#   Chunk 262: Processed 26,200,000 total | Filtered so far: 255,445
#   Chunk 263: Processed 26,300,000 total | Filtered so far: 256,726
#   Chunk 264: Processed 26,400,000 total | Filtered so far: 257,967
#   Chunk 265: Processed 26,500,000 total | Filtered so far: 259,410
#   Chunk 266: Processed 26,600,000 total | Filtered so far: 260,716
#   Chunk 267: Processed 26,700,000 total | Filtered so far: 262,037
#   Chunk 268: Processed 26,800,000 total | Filtered so far: 262,726
#   Chunk 269: Processed 26,900,000 total | Filtered so far: 264,186
#   Chunk 270: Processed 27,000,000 total | Filtered so far: 265,697
#   Chunk 271: Processed 27,100,000 total | Filtered so far: 267,365
#   Chunk 272: Processed 27,200,000 total | Filtered so far: 268,756
#   Chunk 273: Processed 27,300,000 total | Filtered so far: 270,348
#   Chunk 274: Processed 27,400,000 total | Filtered so far: 271,768
#   Chunk 275: Processed 27,500,000 total | Filtered so far: 273,388
#   Chunk 276: Processed 27,600,000 total | Filtered so far: 274,608
#   Chunk 277: Processed 27,700,000 total | Filtered so far: 276,205
#   Chunk 278: Processed 27,800,000 total | Filtered so far: 278,143
#   Chunk 279: Processed 27,900,000 total | Filtered so far: 279,824
#   Chunk 280: Processed 28,000,000 total | Filtered so far: 281,364
#   Chunk 281: Processed 28,100,000 total | Filtered so far: 283,175
#   Chunk 282: Processed 28,200,000 total | Filtered so far: 284,856
#   Chunk 283: Processed 28,300,000 total | Filtered so far: 286,574
#   Chunk 284: Processed 28,400,000 total | Filtered so far: 288,112
#   Chunk 285: Processed 28,500,000 total | Filtered so far: 289,369
#   Chunk 286: Processed 28,600,000 total | Filtered so far: 291,099
#   Chunk 287: Processed 28,700,000 total | Filtered so far: 292,727
#   Chunk 288: Processed 28,800,000 total | Filtered so far: 294,122
#   Chunk 289: Processed 28,900,000 total | Filtered so far: 295,604
#   Chunk 290: Processed 29,000,000 total | Filtered so far: 297,066
#   Chunk 291: Processed 29,100,000 total | Filtered so far: 297,976
#   Chunk 292: Processed 29,200,000 total | Filtered so far: 299,210
#   Chunk 293: Processed 29,300,000 total | Filtered so far: 300,851
#   Chunk 294: Processed 29,400,000 total | Filtered so far: 302,196
#   Chunk 295: Processed 29,475,453 total | Filtered so far: 303,268
#
# ============================================================
# Total reviews scanned: 29,475,453
# Filtered reviews: 303,268
# Retention rate: 1.03%
# ============================================================
#
# ============================================================
# Processing: Electronics
# ============================================================
# Loading and filtering reviews in chunks...
#   Chunk 1: Processed 100,000 total | Filtered so far: 3,912
#   Chunk 2: Processed 200,000 total | Filtered so far: 6,649
#   Chunk 3: Processed 300,000 total | Filtered so far: 9,612
#   Chunk 4: Processed 400,000 total | Filtered so far: 12,649
#   Chunk 5: Processed 500,000 total | Filtered so far: 15,590
#   Chunk 6: Processed 600,000 total | Filtered so far: 18,235
#   Chunk 7: Processed 700,000 total | Filtered so far: 21,638
#   Chunk 8: Processed 800,000 total | Filtered so far: 24,406
#   Chunk 9: Processed 900,000 total | Filtered so far: 27,003
#   Chunk 10: Processed 1,000,000 total | Filtered so far: 30,038
#   Chunk 11: Processed 1,100,000 total | Filtered so far: 33,218
#   Chunk 12: Processed 1,200,000 total | Filtered so far: 36,322
#   Chunk 13: Processed 1,300,000 total | Filtered so far: 39,696
#   Chunk 14: Processed 1,400,000 total | Filtered so far: 42,781
#   Chunk 15: Processed 1,500,000 total | Filtered so far: 46,331
#   Chunk 16: Processed 1,600,000 total | Filtered so far: 49,359
#   Chunk 17: Processed 1,700,000 total | Filtered so far: 52,969
#   Chunk 18: Processed 1,800,000 total | Filtered so far: 56,138
#   Chunk 19: Processed 1,900,000 total | Filtered so far: 59,461
#   Chunk 20: Processed 2,000,000 total | Filtered so far: 62,158
#   Chunk 21: Processed 2,100,000 total | Filtered so far: 65,556
#   Chunk 22: Processed 2,200,000 total | Filtered so far: 69,269
#   Chunk 23: Processed 2,300,000 total | Filtered so far: 72,682
#   Chunk 24: Processed 2,400,000 total | Filtered so far: 76,258
#   Chunk 25: Processed 2,500,000 total | Filtered so far: 79,484
#   Chunk 26: Processed 2,600,000 total | Filtered so far: 83,391
#   Chunk 27: Processed 2,700,000 total | Filtered so far: 87,190
#   Chunk 28: Processed 2,800,000 total | Filtered so far: 91,152
#   Chunk 29: Processed 2,900,000 total | Filtered so far: 94,067
#   Chunk 30: Processed 3,000,000 total | Filtered so far: 96,838
#   Chunk 31: Processed 3,100,000 total | Filtered so far: 100,093
#   Chunk 32: Processed 3,200,000 total | Filtered so far: 102,807
#   Chunk 33: Processed 3,300,000 total | Filtered so far: 105,621
#   Chunk 34: Processed 3,400,000 total | Filtered so far: 108,928
#   Chunk 35: Processed 3,500,000 total | Filtered so far: 111,659
#   Chunk 36: Processed 3,600,000 total | Filtered so far: 115,373
#   Chunk 37: Processed 3,700,000 total | Filtered so far: 118,072
#   Chunk 38: Processed 3,800,000 total | Filtered so far: 120,937
#   Chunk 39: Processed 3,900,000 total | Filtered so far: 123,241
#   Chunk 40: Processed 4,000,000 total | Filtered so far: 126,652
#   Chunk 41: Processed 4,100,000 total | Filtered so far: 130,239
#   Chunk 42: Processed 4,200,000 total | Filtered so far: 133,191
#   Chunk 43: Processed 4,300,000 total | Filtered so far: 136,618
#   Chunk 44: Processed 4,400,000 total | Filtered so far: 140,134
#   Chunk 45: Processed 4,500,000 total | Filtered so far: 143,566
#   Chunk 46: Processed 4,600,000 total | Filtered so far: 146,907
#   Chunk 47: Processed 4,700,000 total | Filtered so far: 150,085
#   Chunk 48: Processed 4,800,000 total | Filtered so far: 153,405
#   Chunk 49: Processed 4,900,000 total | Filtered so far: 157,101
#   Chunk 50: Processed 5,000,000 total | Filtered so far: 160,507
#   Chunk 51: Processed 5,100,000 total | Filtered so far: 163,290
#   Chunk 52: Processed 5,200,000 total | Filtered so far: 166,662
#   Chunk 53: Processed 5,300,000 total | Filtered so far: 171,406
#   Chunk 54: Processed 5,400,000 total | Filtered so far: 175,749
#   Chunk 55: Processed 5,500,000 total | Filtered so far: 178,784
#   Chunk 56: Processed 5,600,000 total | Filtered so far: 181,341
#   Chunk 57: Processed 5,700,000 total | Filtered so far: 184,351
#   Chunk 58: Processed 5,800,000 total | Filtered so far: 187,373
#   Chunk 59: Processed 5,900,000 total | Filtered so far: 191,315
#   Chunk 60: Processed 6,000,000 total | Filtered so far: 194,164
#   Chunk 61: Processed 6,100,000 total | Filtered so far: 197,807
#   Chunk 62: Processed 6,200,000 total | Filtered so far: 200,857
#   Chunk 63: Processed 6,300,000 total | Filtered so far: 204,028
#   Chunk 64: Processed 6,400,000 total | Filtered so far: 207,226
#   Chunk 65: Processed 6,500,000 total | Filtered so far: 211,259
#   Chunk 66: Processed 6,600,000 total | Filtered so far: 215,481
#   Chunk 67: Processed 6,700,000 total | Filtered so far: 218,445
#   Chunk 68: Processed 6,800,000 total | Filtered so far: 221,229
#   Chunk 69: Processed 6,900,000 total | Filtered so far: 224,097
#   Chunk 70: Processed 7,000,000 total | Filtered so far: 227,198
#   Chunk 71: Processed 7,100,000 total | Filtered so far: 230,365
#   Chunk 72: Processed 7,200,000 total | Filtered so far: 233,562
#   Chunk 73: Processed 7,300,000 total | Filtered so far: 236,607
#   Chunk 74: Processed 7,400,000 total | Filtered so far: 240,148
#   Chunk 75: Processed 7,500,000 total | Filtered so far: 243,512
#   Chunk 76: Processed 7,600,000 total | Filtered so far: 246,858
#   Chunk 77: Processed 7,700,000 total | Filtered so far: 249,140
#   Chunk 78: Processed 7,800,000 total | Filtered so far: 251,552
#   Chunk 79: Processed 7,900,000 total | Filtered so far: 254,248
#   Chunk 80: Processed 8,000,000 total | Filtered so far: 257,250
#   Chunk 81: Processed 8,100,000 total | Filtered so far: 260,086
#   Chunk 82: Processed 8,200,000 total | Filtered so far: 263,344
#   Chunk 83: Processed 8,300,000 total | Filtered so far: 266,801
#   Chunk 84: Processed 8,400,000 total | Filtered so far: 269,951
#   Chunk 85: Processed 8,500,000 total | Filtered so far: 273,474
#   Chunk 86: Processed 8,600,000 total | Filtered so far: 277,305
#   Chunk 87: Processed 8,700,000 total | Filtered so far: 280,669
#   Chunk 88: Processed 8,800,000 total | Filtered so far: 283,944
#   Chunk 89: Processed 8,900,000 total | Filtered so far: 287,154
#   Chunk 90: Processed 9,000,000 total | Filtered so far: 290,483
#   Chunk 91: Processed 9,100,000 total | Filtered so far: 294,367
#   Chunk 92: Processed 9,200,000 total | Filtered so far: 297,893
#   Chunk 93: Processed 9,300,000 total | Filtered so far: 301,943
#   Chunk 94: Processed 9,400,000 total | Filtered so far: 305,513
#   Chunk 95: Processed 9,500,000 total | Filtered so far: 308,862
#   Chunk 96: Processed 9,600,000 total | Filtered so far: 312,870
#   Chunk 97: Processed 9,700,000 total | Filtered so far: 316,231
#   Chunk 98: Processed 9,800,000 total | Filtered so far: 320,212
#   Chunk 99: Processed 9,900,000 total | Filtered so far: 323,617
#   Chunk 100: Processed 10,000,000 total | Filtered so far: 326,799
#   Chunk 101: Processed 10,100,000 total | Filtered so far: 329,781
#   Chunk 102: Processed 10,200,000 total | Filtered so far: 332,668
#   Chunk 103: Processed 10,300,000 total | Filtered so far: 335,334
#   Chunk 104: Processed 10,400,000 total | Filtered so far: 338,031
#   Chunk 105: Processed 10,500,000 total | Filtered so far: 340,705
#   Chunk 106: Processed 10,600,000 total | Filtered so far: 343,399
#   Chunk 107: Processed 10,700,000 total | Filtered so far: 346,501
#   Chunk 108: Processed 10,800,000 total | Filtered so far: 350,216
#   Chunk 109: Processed 10,900,000 total | Filtered so far: 353,381
#   Chunk 110: Processed 11,000,000 total | Filtered so far: 356,162
#   Chunk 111: Processed 11,100,000 total | Filtered so far: 359,339
#   Chunk 112: Processed 11,200,000 total | Filtered so far: 362,453
#   Chunk 113: Processed 11,300,000 total | Filtered so far: 365,464
#   Chunk 114: Processed 11,400,000 total | Filtered so far: 368,818
#   Chunk 115: Processed 11,500,000 total | Filtered so far: 372,434
#   Chunk 116: Processed 11,600,000 total | Filtered so far: 375,434
#   Chunk 117: Processed 11,700,000 total | Filtered so far: 378,748
#   Chunk 118: Processed 11,800,000 total | Filtered so far: 381,801
#   Chunk 119: Processed 11,900,000 total | Filtered so far: 384,951
#   Chunk 120: Processed 12,000,000 total | Filtered so far: 388,661
#   Chunk 121: Processed 12,100,000 total | Filtered so far: 391,626
#   Chunk 122: Processed 12,200,000 total | Filtered so far: 394,803
#   Chunk 123: Processed 12,300,000 total | Filtered so far: 398,133
#   Chunk 124: Processed 12,400,000 total | Filtered so far: 401,564
#   Chunk 125: Processed 12,500,000 total | Filtered so far: 404,388
#   Chunk 126: Processed 12,600,000 total | Filtered so far: 407,985
#   Chunk 127: Processed 12,700,000 total | Filtered so far: 411,223
#   Chunk 128: Processed 12,800,000 total | Filtered so far: 414,433
#   Chunk 129: Processed 12,900,000 total | Filtered so far: 418,249
#   Chunk 130: Processed 13,000,000 total | Filtered so far: 421,432
#   Chunk 131: Processed 13,100,000 total | Filtered so far: 424,651
#   Chunk 132: Processed 13,200,000 total | Filtered so far: 427,700
#   Chunk 133: Processed 13,300,000 total | Filtered so far: 431,515
#   Chunk 134: Processed 13,400,000 total | Filtered so far: 434,480
#   Chunk 135: Processed 13,500,000 total | Filtered so far: 437,448
#   Chunk 136: Processed 13,600,000 total | Filtered so far: 440,481
#   Chunk 137: Processed 13,700,000 total | Filtered so far: 443,582
#   Chunk 138: Processed 13,800,000 total | Filtered so far: 447,197
#   Chunk 139: Processed 13,900,000 total | Filtered so far: 450,578
#   Chunk 140: Processed 14,000,000 total | Filtered so far: 453,711
#   Chunk 141: Processed 14,100,000 total | Filtered so far: 457,075
#   Chunk 142: Processed 14,200,000 total | Filtered so far: 460,576
#   Chunk 143: Processed 14,300,000 total | Filtered so far: 463,656
#   Chunk 144: Processed 14,400,000 total | Filtered so far: 466,648
#   Chunk 145: Processed 14,500,000 total | Filtered so far: 470,013
#   Chunk 146: Processed 14,600,000 total | Filtered so far: 473,656
#   Chunk 147: Processed 14,700,000 total | Filtered so far: 478,306
#   Chunk 148: Processed 14,800,000 total | Filtered so far: 482,502
#   Chunk 149: Processed 14,900,000 total | Filtered so far: 486,668
#   Chunk 150: Processed 15,000,000 total | Filtered so far: 490,493
#   Chunk 151: Processed 15,100,000 total | Filtered so far: 494,772
#   Chunk 152: Processed 15,200,000 total | Filtered so far: 498,842
#   Chunk 153: Processed 15,300,000 total | Filtered so far: 503,357
#   Chunk 154: Processed 15,400,000 total | Filtered so far: 507,494
#   Chunk 155: Processed 15,500,000 total | Filtered so far: 510,646
#   Chunk 156: Processed 15,600,000 total | Filtered so far: 514,137
#   Chunk 157: Processed 15,700,000 total | Filtered so far: 518,581
#   Chunk 158: Processed 15,800,000 total | Filtered so far: 521,823
#   Chunk 159: Processed 15,900,000 total | Filtered so far: 525,610
#   Chunk 160: Processed 16,000,000 total | Filtered so far: 529,369
#   Chunk 161: Processed 16,100,000 total | Filtered so far: 533,366
#   Chunk 162: Processed 16,200,000 total | Filtered so far: 536,203
#   Chunk 163: Processed 16,300,000 total | Filtered so far: 539,168
#   Chunk 164: Processed 16,400,000 total | Filtered so far: 542,252
#   Chunk 165: Processed 16,500,000 total | Filtered so far: 545,332
#   Chunk 166: Processed 16,600,000 total | Filtered so far: 548,645
#   Chunk 167: Processed 16,700,000 total | Filtered so far: 552,217
#   Chunk 168: Processed 16,800,000 total | Filtered so far: 556,765
#   Chunk 169: Processed 16,900,000 total | Filtered so far: 560,185
#   Chunk 170: Processed 17,000,000 total | Filtered so far: 563,925
#   Chunk 171: Processed 17,100,000 total | Filtered so far: 568,222
#   Chunk 172: Processed 17,200,000 total | Filtered so far: 573,164
#   Chunk 173: Processed 17,300,000 total | Filtered so far: 577,371
#   Chunk 174: Processed 17,400,000 total | Filtered so far: 581,294
#   Chunk 175: Processed 17,500,000 total | Filtered so far: 585,547
#   Chunk 176: Processed 17,600,000 total | Filtered so far: 589,040
#   Chunk 177: Processed 17,700,000 total | Filtered so far: 592,623
#   Chunk 178: Processed 17,800,000 total | Filtered so far: 596,561
#   Chunk 179: Processed 17,900,000 total | Filtered so far: 600,139
#   Chunk 180: Processed 18,000,000 total | Filtered so far: 603,586
#   Chunk 181: Processed 18,100,000 total | Filtered so far: 606,408
#   Chunk 182: Processed 18,200,000 total | Filtered so far: 610,304
#   Chunk 183: Processed 18,300,000 total | Filtered so far: 614,635
#   Chunk 184: Processed 18,400,000 total | Filtered so far: 618,438
#   Chunk 185: Processed 18,500,000 total | Filtered so far: 622,376
#   Chunk 186: Processed 18,600,000 total | Filtered so far: 626,133
#   Chunk 187: Processed 18,700,000 total | Filtered so far: 629,992
#   Chunk 188: Processed 18,800,000 total | Filtered so far: 633,947
# ...
#   Chunk 269: Processed 26,900,000 total | Filtered so far: 950,326
#   Chunk 270: Processed 27,000,000 total | Filtered so far: 954,596
#   Chunk 271: Processed 27,100,000 total | Filtered so far: 958,044
#   Chunk 272: Processed 27,200,000 total | Filtered so far: 961,921
#   Chunk 273: Processed 27,300,000 total | Filtered so far: 965,620
#   Chunk 274: Processed 27,400,000 total | Filtered so far: 968,928
#   Chunk 275: Processed 27,500,000 total | Filtered so far: 972,462
#   Chunk 276: Processed 27,600,000 total | Filtered so far: 976,877
#   Chunk 277: Processed 27,700,000 total | Filtered so far: 981,334
#   Chunk 278: Processed 27,800,000 total | Filtered so far: 985,939
#   Chunk 279: Processed 27,900,000 total | Filtered so far: 989,805
#   Chunk 280: Processed 28,000,000 total | Filtered so far: 994,446
#   Chunk 281: Processed 28,100,000 total | Filtered so far: 998,464
#   Chunk 282: Processed 28,200,000 total | Filtered so far: 1,002,487
#   Chunk 283: Processed 28,300,000 total | Filtered so far: 1,007,112
#   Chunk 284: Processed 28,400,000 total | Filtered so far: 1,010,838
#   Chunk 285: Processed 28,500,000 total | Filtered so far: 1,014,335
#   Chunk 286: Processed 28,600,000 total | Filtered so far: 1,018,684
#   Chunk 287: Processed 28,700,000 total | Filtered so far: 1,021,700
#   Chunk 288: Processed 28,800,000 total | Filtered so far: 1,025,798
#   Chunk 289: Processed 28,900,000 total | Filtered so far: 1,029,637
#   Chunk 290: Processed 29,000,000 total | Filtered so far: 1,033,768
#   Chunk 291: Processed 29,100,000 total | Filtered so far: 1,037,962
#   Chunk 292: Processed 29,200,000 total | Filtered so far: 1,042,630
#   Chunk 293: Processed 29,300,000 total | Filtered so far: 1,046,238
#   Chunk 294: Processed 29,400,000 total | Filtered so far: 1,050,571
#   Chunk 295: Processed 29,500,000 total | Filtered so far: 1,054,543
#   Chunk 296: Processed 29,600,000 total | Filtered so far: 1,058,363
#   Chunk 297: Processed 29,700,000 total | Filtered so far: 1,061,895
#   Chunk 298: Processed 29,800,000 total | Filtered so far: 1,066,852
#   Chunk 299: Processed 29,900,000 total | Filtered so far: 1,070,539
#   Chunk 300: Processed 30,000,000 total | Filtered so far: 1,074,912
#   Chunk 301: Processed 30,100,000 total | Filtered so far: 1,077,966
#   Chunk 302: Processed 30,200,000 total | Filtered so far: 1,082,997
#   Chunk 303: Processed 30,300,000 total | Filtered so far: 1,087,133
#   Chunk 304: Processed 30,400,000 total | Filtered so far: 1,091,978
#   Chunk 305: Processed 30,500,000 total | Filtered so far: 1,096,604
#   Chunk 306: Processed 30,600,000 total | Filtered so far: 1,101,853
#   Chunk 307: Processed 30,700,000 total | Filtered so far: 1,105,957
#   Chunk 308: Processed 30,800,000 total | Filtered so far: 1,110,688
#   Chunk 309: Processed 30,900,000 total | Filtered so far: 1,114,688
#   Chunk 310: Processed 31,000,000 total | Filtered so far: 1,119,711
#   Chunk 311: Processed 31,100,000 total | Filtered so far: 1,123,164
#   Chunk 312: Processed 31,200,000 total | Filtered so far: 1,127,347
#   Chunk 313: Processed 31,300,000 total | Filtered so far: 1,133,022
#   Chunk 314: Processed 31,400,000 total | Filtered so far: 1,137,356
#   Chunk 315: Processed 31,500,000 total | Filtered so far: 1,142,031
#   Chunk 316: Processed 31,600,000 total | Filtered so far: 1,145,501
#   Chunk 317: Processed 31,700,000 total | Filtered so far: 1,149,595
#   Chunk 318: Processed 31,800,000 total | Filtered so far: 1,153,310
#   Chunk 319: Processed 31,900,000 total | Filtered so far: 1,156,465
#   Chunk 320: Processed 32,000,000 total | Filtered so far: 1,160,511
#   Chunk 321: Processed 32,100,000 total | Filtered so far: 1,164,102
#   Chunk 322: Processed 32,200,000 total | Filtered so far: 1,168,460
#   Chunk 323: Processed 32,300,000 total | Filtered so far: 1,172,709
#   Chunk 324: Processed 32,400,000 total | Filtered so far: 1,176,990
#   Chunk 325: Processed 32,500,000 total | Filtered so far: 1,180,858
#   Chunk 326: Processed 32,600,000 total | Filtered so far: 1,184,694
#   Chunk 327: Processed 32,700,000 total | Filtered so far: 1,188,694
#   Chunk 328: Processed 32,800,000 total | Filtered so far: 1,192,390
#   Chunk 329: Processed 32,900,000 total | Filtered so far: 1,195,767
#   Chunk 330: Processed 33,000,000 total | Filtered so far: 1,199,682
#   Chunk 331: Processed 33,100,000 total | Filtered so far: 1,204,081
#   Chunk 332: Processed 33,200,000 total | Filtered so far: 1,207,681
#   Chunk 333: Processed 33,300,000 total | Filtered so far: 1,211,451
#   Chunk 334: Processed 33,400,000 total | Filtered so far: 1,215,899
#   Chunk 335: Processed 33,500,000 total | Filtered so far: 1,219,735
#   Chunk 336: Processed 33,600,000 total | Filtered so far: 1,224,011
#   Chunk 337: Processed 33,700,000 total | Filtered so far: 1,228,430
#   Chunk 338: Processed 33,800,000 total | Filtered so far: 1,232,580
#   Chunk 339: Processed 33,900,000 total | Filtered so far: 1,236,186
#   Chunk 340: Processed 34,000,000 total | Filtered so far: 1,240,435
#   Chunk 341: Processed 34,100,000 total | Filtered so far: 1,244,477
#   Chunk 342: Processed 34,200,000 total | Filtered so far: 1,248,184
#   Chunk 343: Processed 34,300,000 total | Filtered so far: 1,252,526
#   Chunk 344: Processed 34,400,000 total | Filtered so far: 1,256,724
#   Chunk 345: Processed 34,500,000 total | Filtered so far: 1,262,143
#   Chunk 346: Processed 34,600,000 total | Filtered so far: 1,266,008
#   Chunk 347: Processed 34,700,000 total | Filtered so far: 1,269,617
#   Chunk 348: Processed 34,800,000 total | Filtered so far: 1,273,696
#   Chunk 349: Processed 34,900,000 total | Filtered so far: 1,277,969
#   Chunk 350: Processed 35,000,000 total | Filtered so far: 1,281,992
#   Chunk 351: Processed 35,100,000 total | Filtered so far: 1,285,945
#   Chunk 352: Processed 35,200,000 total | Filtered so far: 1,289,960
#   Chunk 353: Processed 35,300,000 total | Filtered so far: 1,293,872
#   Chunk 354: Processed 35,400,000 total | Filtered so far: 1,298,031
#   Chunk 355: Processed 35,500,000 total | Filtered so far: 1,302,099
#   Chunk 356: Processed 35,600,000 total | Filtered so far: 1,305,986
#   Chunk 357: Processed 35,700,000 total | Filtered so far: 1,310,094
#   Chunk 358: Processed 35,800,000 total | Filtered so far: 1,314,136
#   Chunk 359: Processed 35,900,000 total | Filtered so far: 1,318,015
#   Chunk 360: Processed 36,000,000 total | Filtered so far: 1,322,758
#   Chunk 361: Processed 36,100,000 total | Filtered so far: 1,327,368
#   Chunk 362: Processed 36,200,000 total | Filtered so far: 1,332,098
#   Chunk 363: Processed 36,300,000 total | Filtered so far: 1,336,410
#   Chunk 364: Processed 36,400,000 total | Filtered so far: 1,341,391
#   Chunk 365: Processed 36,500,000 total | Filtered so far: 1,345,719
#   Chunk 366: Processed 36,600,000 total | Filtered so far: 1,349,736
#   Chunk 367: Processed 36,700,000 total | Filtered so far: 1,354,087
#   Chunk 368: Processed 36,800,000 total | Filtered so far: 1,358,404
#   Chunk 369: Processed 36,900,000 total | Filtered so far: 1,362,836
#   Chunk 370: Processed 37,000,000 total | Filtered so far: 1,367,322
#   Chunk 371: Processed 37,100,000 total | Filtered so far: 1,371,675
#   Chunk 372: Processed 37,200,000 total | Filtered so far: 1,377,046
#   Chunk 373: Processed 37,300,000 total | Filtered so far: 1,381,394
#   Chunk 374: Processed 37,400,000 total | Filtered so far: 1,385,928
#   Chunk 375: Processed 37,500,000 total | Filtered so far: 1,390,288
#   Chunk 376: Processed 37,600,000 total | Filtered so far: 1,395,358
#   Chunk 377: Processed 37,700,000 total | Filtered so far: 1,400,612
#   Chunk 378: Processed 37,800,000 total | Filtered so far: 1,407,228
#   Chunk 379: Processed 37,900,000 total | Filtered so far: 1,413,237
#   Chunk 380: Processed 38,000,000 total | Filtered so far: 1,418,830
#   Chunk 381: Processed 38,100,000 total | Filtered so far: 1,423,721
#   Chunk 382: Processed 38,200,000 total | Filtered so far: 1,429,362
#   Chunk 383: Processed 38,300,000 total | Filtered so far: 1,435,034
#   Chunk 384: Processed 38,400,000 total | Filtered so far: 1,439,300
#   Chunk 385: Processed 38,500,000 total | Filtered so far: 1,443,596
#   Chunk 386: Processed 38,600,000 total | Filtered so far: 1,448,606
#   Chunk 387: Processed 38,700,000 total | Filtered so far: 1,453,658
#   Chunk 388: Processed 38,800,000 total | Filtered so far: 1,459,467
#   Chunk 389: Processed 38,900,000 total | Filtered so far: 1,464,610
#   Chunk 390: Processed 39,000,000 total | Filtered so far: 1,469,828
#   Chunk 391: Processed 39,100,000 total | Filtered so far: 1,475,472
#   Chunk 392: Processed 39,200,000 total | Filtered so far: 1,480,414
#   Chunk 393: Processed 39,300,000 total | Filtered so far: 1,485,966
#   Chunk 394: Processed 39,400,000 total | Filtered so far: 1,490,926
#   Chunk 395: Processed 39,500,000 total | Filtered so far: 1,495,576
#   Chunk 396: Processed 39,600,000 total | Filtered so far: 1,499,844
#   Chunk 397: Processed 39,700,000 total | Filtered so far: 1,504,215
#   Chunk 398: Processed 39,800,000 total | Filtered so far: 1,509,626
#   Chunk 399: Processed 39,900,000 total | Filtered so far: 1,516,419
#   Chunk 400: Processed 40,000,000 total | Filtered so far: 1,520,813
#   Chunk 401: Processed 40,100,000 total | Filtered so far: 1,525,498
#   Chunk 402: Processed 40,200,000 total | Filtered so far: 1,529,679
#   Chunk 403: Processed 40,300,000 total | Filtered so far: 1,533,650
#   Chunk 404: Processed 40,400,000 total | Filtered so far: 1,538,806
#   Chunk 405: Processed 40,500,000 total | Filtered so far: 1,543,630
#   Chunk 406: Processed 40,600,000 total | Filtered so far: 1,548,253
#   Chunk 407: Processed 40,700,000 total | Filtered so far: 1,552,980
#   Chunk 408: Processed 40,800,000 total | Filtered so far: 1,558,075
#   Chunk 409: Processed 40,900,000 total | Filtered so far: 1,562,603
#   Chunk 410: Processed 41,000,000 total | Filtered so far: 1,567,144
#   Chunk 411: Processed 41,100,000 total | Filtered so far: 1,572,096
#   Chunk 412: Processed 41,200,000 total | Filtered so far: 1,576,736
#   Chunk 413: Processed 41,300,000 total | Filtered so far: 1,581,610
#   Chunk 414: Processed 41,400,000 total | Filtered so far: 1,586,470
#   Chunk 415: Processed 41,500,000 total | Filtered so far: 1,591,213
#   Chunk 416: Processed 41,600,000 total | Filtered so far: 1,596,061
#   Chunk 417: Processed 41,700,000 total | Filtered so far: 1,600,477
#   Chunk 418: Processed 41,800,000 total | Filtered so far: 1,605,458
#   Chunk 419: Processed 41,900,000 total | Filtered so far: 1,610,933
#   Chunk 420: Processed 42,000,000 total | Filtered so far: 1,616,756
#   Chunk 421: Processed 42,100,000 total | Filtered so far: 1,622,172
#   Chunk 422: Processed 42,200,000 total | Filtered so far: 1,628,065
#   Chunk 423: Processed 42,300,000 total | Filtered so far: 1,633,743
#   Chunk 424: Processed 42,400,000 total | Filtered so far: 1,639,969
#   Chunk 425: Processed 42,500,000 total | Filtered so far: 1,645,809
#   Chunk 426: Processed 42,600,000 total | Filtered so far: 1,651,562
#   Chunk 427: Processed 42,700,000 total | Filtered so far: 1,656,658
#   Chunk 428: Processed 42,800,000 total | Filtered so far: 1,661,341
#   Chunk 429: Processed 42,900,000 total | Filtered so far: 1,666,651
#   Chunk 430: Processed 43,000,000 total | Filtered so far: 1,672,060
#   Chunk 431: Processed 43,100,000 total | Filtered so far: 1,677,299
#   Chunk 432: Processed 43,200,000 total | Filtered so far: 1,682,053
#   Chunk 433: Processed 43,300,000 total | Filtered so far: 1,687,252
#   Chunk 434: Processed 43,400,000 total | Filtered so far: 1,692,568
#   Chunk 435: Processed 43,500,000 total | Filtered so far: 1,697,227
#   Chunk 436: Processed 43,600,000 total | Filtered so far: 1,703,168
#   Chunk 437: Processed 43,700,000 total | Filtered so far: 1,708,549
#   Chunk 438: Processed 43,800,000 total | Filtered so far: 1,713,168
#   Chunk 439: Processed 43,886,944 total | Filtered so far: 1,717,328
#
# ============================================================
# Total reviews scanned: 43,886,944
# Filtered reviews: 1,717,328
# Retention rate: 3.91%
# ============================================================
#
# ============================================================
# Processing: Video_Games
# ============================================================
# Loading and filtering reviews in chunks...
#   Chunk 1: Processed 100,000 total | Filtered so far: 2,418
#   Chunk 2: Processed 200,000 total | Filtered so far: 5,619
#   Chunk 3: Processed 300,000 total | Filtered so far: 8,671
#   Chunk 4: Processed 400,000 total | Filtered so far: 11,501
#   Chunk 5: Processed 500,000 total | Filtered so far: 14,647
#   Chunk 6: Processed 600,000 total | Filtered so far: 17,775
#   Chunk 7: Processed 700,000 total | Filtered so far: 20,613
#   Chunk 8: Processed 800,000 total | Filtered so far: 23,129
#   Chunk 9: Processed 900,000 total | Filtered so far: 26,397
#   Chunk 10: Processed 1,000,000 total | Filtered so far: 29,445
#   Chunk 11: Processed 1,100,000 total | Filtered so far: 32,168
#   Chunk 12: Processed 1,200,000 total | Filtered so far: 35,319
#   Chunk 13: Processed 1,300,000 total | Filtered so far: 38,102
#   Chunk 14: Processed 1,400,000 total | Filtered so far: 41,364
#   Chunk 15: Processed 1,500,000 total | Filtered so far: 45,157
#   Chunk 16: Processed 1,600,000 total | Filtered so far: 48,438
#   Chunk 17: Processed 1,700,000 total | Filtered so far: 51,991
#   Chunk 18: Processed 1,800,000 total | Filtered so far: 55,566
#   Chunk 19: Processed 1,900,000 total | Filtered so far: 58,693
#   Chunk 20: Processed 2,000,000 total | Filtered so far: 62,913
#   Chunk 21: Processed 2,100,000 total | Filtered so far: 66,652
#   Chunk 22: Processed 2,200,000 total | Filtered so far: 70,405
#   Chunk 23: Processed 2,300,000 total | Filtered so far: 73,900
#   Chunk 24: Processed 2,400,000 total | Filtered so far: 77,427
#   Chunk 25: Processed 2,500,000 total | Filtered so far: 81,119
#   Chunk 26: Processed 2,600,000 total | Filtered so far: 84,663
#   Chunk 27: Processed 2,700,000 total | Filtered so far: 88,303
#   Chunk 28: Processed 2,800,000 total | Filtered so far: 92,076
#   Chunk 29: Processed 2,900,000 total | Filtered so far: 95,922
#   Chunk 30: Processed 3,000,000 total | Filtered so far: 100,144
#   Chunk 31: Processed 3,100,000 total | Filtered so far: 105,058
#   Chunk 32: Processed 3,200,000 total | Filtered so far: 108,844
#   Chunk 33: Processed 3,300,000 total | Filtered so far: 112,569
#   Chunk 34: Processed 3,400,000 total | Filtered so far: 116,027
#   Chunk 35: Processed 3,500,000 total | Filtered so far: 119,635
#   Chunk 36: Processed 3,600,000 total | Filtered so far: 123,322
#   Chunk 37: Processed 3,700,000 total | Filtered so far: 127,211
#   Chunk 38: Processed 3,800,000 total | Filtered so far: 131,110
#   Chunk 39: Processed 3,900,000 total | Filtered so far: 136,049
#   Chunk 40: Processed 4,000,000 total | Filtered so far: 141,205
#   Chunk 41: Processed 4,100,000 total | Filtered so far: 145,968
#   Chunk 42: Processed 4,200,000 total | Filtered so far: 149,983
#   Chunk 43: Processed 4,300,000 total | Filtered so far: 154,121
#   Chunk 44: Processed 4,400,000 total | Filtered so far: 159,273
#   Chunk 45: Processed 4,500,000 total | Filtered so far: 165,083
#   Chunk 46: Processed 4,600,000 total | Filtered so far: 170,597
#   Chunk 47: Processed 4,624,615 total | Filtered so far: 171,854
#
# ============================================================
# Total reviews scanned: 4,624,615
# Filtered reviews: 171,854
# Retention rate: 3.72%
# ============================================================
#
# ================================================================================
# SUMMARY STATISTICS
# ================================================================================
#       Category  Total Reviews  Filtered Reviews Retention %
# Amazon_Fashion        2500939            133984       5.36%
#     Automotive       19955450           1123953       5.63%
#          Books       29475453            303268       1.03%
#    Electronics       43886944           1717328       3.91%
#    Video_Games        4624615            171854       3.72%
# ================================================================================

# %% [markdown]
# ## Step 3: Create Balanced Datasets (Max 10,000 entries each)

# %%
# Create balanced datasets for each category
output_paths = []

for data in filtered_data:
    category = data['category']
    df = data['df']

    output_path = create_balanced_dataset(df, category, dataset_path, max_entries=MAX_BALANCED_ENTRIES)
    output_paths.append(output_path)

print("\n" + "="*80)
print("ALL DATASETS CREATED SUCCESSFULLY")
print("="*80)
print(f"\nCreated {len(output_paths)} balanced datasets:")
for path in output_paths:
    print(f"  {os.path.basename(path)}")
# Out:
# Creating balanced dataset for Amazon_Fashion...
# Original filtered dataset: 133,984 entries
# After removing duplicate products: 98,464 entries
#
# Preprocessing text fields...
# Text preprocessing complete
# Removed 269 entries with empty title or text after preprocessing
# Entries after text cleaning: 98,195
# Dataset shuffled for random sampling
#
# Ratings found: [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0)]
# Target samples per rating: 2000
# Target total entries: 10000
#   Rating 1.0: 16,129 available, sampled 2,000
#   Rating 2.0: 6,946 available, sampled 2,000
#   Rating 3.0: 7,696 available, sampled 2,000
#   Rating 4.0: 12,549 available, sampled 2,000
#   Rating 5.0: 54,875 available, sampled 2,000
#
# Final balanced dataset created: 10,000 entries
#
# Final rating distribution:
#   Rating 1.0: 2,000
#   Rating 2.0: 2,000
#   Rating 3.0: 2,000
#   Rating 4.0: 2,000
#   Rating 5.0: 2,000
#
# Total entries: 10,000
# Success: Exactly 10,000 entries as required
#
# Sample of preprocessed data:
#   Rating: 4.0
#   Title: great comfortable shoe....
#   Text: surprisingly comfortable shoe. very cute. i love that they can be worn laced up ...
#
# Saved balanced dataset to: Amazon_Fashion_balanced.csv
# Ready for NLP/LLM processing
#
# Creating balanced dataset for Automotive...
# Original filtered dataset: 1,123,953 entries
# After removing duplicate products: 455,689 entries
#
# Preprocessing text fields...
# Text preprocessing complete
# Removed 783 entries with empty title or text after preprocessing
# Entries after text cleaning: 454,906
# Dataset shuffled for random sampling
#
# Ratings found: [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0)]
# Target samples per rating: 2000
# Target total entries: 10000
#   Rating 1.0: 86,651 available, sampled 2,000
#   Rating 2.0: 25,945 available, sampled 2,000
#   Rating 3.0: 29,904 available, sampled 2,000
#   Rating 4.0: 47,813 available, sampled 2,000
#   Rating 5.0: 264,593 available, sampled 2,000
#
# Final balanced dataset created: 10,000 entries
#
# Final rating distribution:
#   Rating 1.0: 2,000
#   Rating 2.0: 2,000
#   Rating 3.0: 2,000
#   Rating 4.0: 2,000
#   Rating 5.0: 2,000
#
# Total entries: 10,000
# Success: Exactly 10,000 entries as required
#
# Sample of preprocessed data:
#   Rating: 4.0
#   Title: 4 star...
#   Text: the only reason i am giving it a 4 star review it s because it is missing a bolt...
#
# Saved balanced dataset to: Automotive_balanced.csv
# Ready for NLP/LLM processing
#
# Creating balanced dataset for Books...
# Original filtered dataset: 303,268 entries
# After removing duplicate products: 180,709 entries
#
# Preprocessing text fields...
# Text preprocessing complete
# Removed 307 entries with empty title or text after preprocessing
# Entries after text cleaning: 180,402
# Dataset shuffled for random sampling
#
# Ratings found: [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0)]
# Target samples per rating: 2000
# Target total entries: 10000
#   Rating 1.0: 25,192 available, sampled 2,000
#   Rating 2.0: 10,842 available, sampled 2,000
#   Rating 3.0: 12,699 available, sampled 2,000
#   Rating 4.0: 15,027 available, sampled 2,000
#   Rating 5.0: 116,642 available, sampled 2,000
#
# Final balanced dataset created: 10,000 entries
#
# Final rating distribution:
#   Rating 1.0: 2,000
#   Rating 2.0: 2,000
#   Rating 3.0: 2,000
#   Rating 4.0: 2,000
#   Rating 5.0: 2,000
#
# Total entries: 10,000
# Success: Exactly 10,000 entries as required
#
# Sample of preprocessed data:
#   Rating: 4.0
#   Title: we ve never had a murder here before....
#   Text: we re going to miss you, she said. we re not used to this sort of excitement in ...
#
# Saved balanced dataset to: Books_balanced.csv
# Ready for NLP/LLM processing
#
# Creating balanced dataset for Electronics...
# Original filtered dataset: 1,717,328 entries
# After removing duplicate products: 449,589 entries
#
# Preprocessing text fields...
# Text preprocessing complete
# Removed 589 entries with empty title or text after preprocessing
# Entries after text cleaning: 449,000
# Dataset shuffled for random sampling
#
# Ratings found: [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0)]
# Target samples per rating: 2000
# Target total entries: 10000
#   Rating 1.0: 75,531 available, sampled 2,000
#   Rating 2.0: 27,403 available, sampled 2,000
#   Rating 3.0: 31,027 available, sampled 2,000
#   Rating 4.0: 50,534 available, sampled 2,000
#   Rating 5.0: 264,505 available, sampled 2,000
#
# Final balanced dataset created: 10,000 entries
#
# Final rating distribution:
#   Rating 1.0: 2,000
#   Rating 2.0: 2,000
#   Rating 3.0: 2,000
#   Rating 4.0: 2,000
#   Rating 5.0: 2,000
#
# Total entries: 10,000
# Success: Exactly 10,000 entries as required
#
# Sample of preprocessed data:
#   Rating: 4.0
#   Title: i bought the rose gold and it is super sparkly and bright...
#   Text: i will never ever misplace my tablet in this cover. .i bought the rose gold and ...
#
# Saved balanced dataset to: Electronics_balanced.csv
# Ready for NLP/LLM processing
#
# Creating balanced dataset for Video_Games...
# Original filtered dataset: 171,854 entries
# After removing duplicate products: 43,986 entries
#
# Preprocessing text fields...
# Text preprocessing complete
# Removed 80 entries with empty title or text after preprocessing
# Entries after text cleaning: 43,906
# Dataset shuffled for random sampling
#
# Ratings found: [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0)]
# Target samples per rating: 2000
# Target total entries: 10000
#   Rating 1.0: 7,034 available, sampled 2,000
#   Rating 2.0: 2,389 available, sampled 2,000
#   Rating 3.0: 3,127 available, sampled 2,000
#   Rating 4.0: 5,362 available, sampled 2,000
#   Rating 5.0: 25,994 available, sampled 2,000
#
# Final balanced dataset created: 10,000 entries
#
# Final rating distribution:
#   Rating 1.0: 2,000
#   Rating 2.0: 2,000
#   Rating 3.0: 2,000
#   Rating 4.0: 2,000
#   Rating 5.0: 2,000
#
# Total entries: 10,000
# Success: Exactly 10,000 entries as required
#
# Sample of preprocessed data:
#   Rating: 4.0
#   Title: glad that i open mine anyway...
#   Text: got a great price of 10 for it. i see why now. i m glad that i open my amiibo an...
#
# Saved balanced dataset to: Video_Games_balanced.csv
# Ready for NLP/LLM processing
#
# ================================================================================
# ALL DATASETS CREATED SUCCESSFULLY
# ================================================================================
#
# Created 5 balanced datasets:
#   Amazon_Fashion_balanced.csv
#   Automotive_balanced.csv
#   Books_balanced.csv
#   Electronics_balanced.csv
#   Video_Games_balanced.csv
